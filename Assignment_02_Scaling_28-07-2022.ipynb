# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('supershops.csv')

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df.shape
# Out:
# (50, 5)

# %%
df.describe()
# Out:
#        Marketing Spend  Administration      Transport         Profit
# count        50.000000       50.000000      49.000000      50.000000
# mean      73721.615600   121344.639600  215331.732449  112012.639200
# std       45902.256482    28017.802755  119665.391550   40306.180338
# min           0.000000    51283.140000       0.000000   14681.400000
# 25%       39936.370000   103730.875000  134050.070000   90138.902500
# 50%       73051.080000   122699.795000  214634.810000  107978.190000
# 75%      101602.800000   144842.180000  299737.290000  139765.977500
# max      165349.200000   182645.560000  471784.100000  192261.830000

# %%
df.isnull().sum()
# Out:
# Marketing Spend    0
# Administration     0
# Transport          1
# Area               0
# Profit             0
# dtype: int64

# %%
df['Transport'].mean()
# Out:
# 215331.73244897963

# %%
df['Transport'].median()
# Out:
# 214634.81

# %%
plt.plot(df.Transport.values)

# %%
df['Transport']=df['Transport'].fillna(int(df['Transport'].median()))
df.isnull().sum()
# Out:
# Marketing Spend    0
# Administration     0
# Transport          0
# Area               0
# Profit             0
# dtype: int64

# %%
plt.plot(df.Transport.values)

# %%
df
# Out:
#     Marketing Spend  Administration  Transport     Area     Profit
# 0         114523.61       136897.80  471784.10    Dhaka  192261.83
# 1         162597.70       151377.59  443898.53      Ctg  191792.06
# 2         153441.51       101145.55  407934.54  Rangpur  191050.39
# 3         144372.41       118671.85  383199.62    Dhaka  182901.99
# 4         142107.34        91391.77  366168.42  Rangpur  166187.94
# 5         131876.90        99814.71  362861.36    Dhaka  156991.12
# 6         134615.46       147198.87  127716.82      Ctg  156122.51
# 7         130298.13       145530.06  323876.68  Rangpur  155752.60
# 8         120542.52       148718.95  311613.29    Dhaka  152211.77
# 9         123334.88       108679.17  304981.62      Ctg  149759.96
# 10        101913.08       110594.11  229160.95  Rangpur  146121.95
# 11        100671.96        91790.61  249744.55      Ctg  144259.40
# 12         93863.75       127320.38  249839.44  Rangpur  141585.52
# ...

# %%
df2=df.copy()
df3=df.copy()
df4=df.copy()

# %% [markdown]
# # Feature Transaction (Scaling)
# - Normalization

# %%
from sklearn.preprocessing import MinMaxScaler
mmscaler=MinMaxScaler()

# %%
df['Marketing Spend']=mmscaler.fit_transform(df[['Marketing Spend']])

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617       136897.80  471784.10    Dhaka  192261.83
# 1         0.983359       151377.59  443898.53      Ctg  191792.06
# 2         0.927985       101145.55  407934.54  Rangpur  191050.39
# 3         0.873136       118671.85  383199.62    Dhaka  182901.99
# 4         0.859438        91391.77  366168.42  Rangpur  166187.94

# %%
df['Administration']=mmscaler.fit_transform(df[['Administration']])
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617        0.651744  471784.10    Dhaka  192261.83
# 1         0.983359        0.761972  443898.53      Ctg  191792.06
# 2         0.927985        0.379579  407934.54  Rangpur  191050.39
# 3         0.873136        0.512998  383199.62    Dhaka  182901.99
# 4         0.859438        0.305328  366168.42  Rangpur  166187.94

# %%
df['Transport']=mmscaler.fit_transform(df[['Transport']])
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617        0.651744   1.000000    Dhaka  192261.83
# 1         0.983359        0.761972   0.940893      Ctg  191792.06
# 2         0.927985        0.379579   0.864664  Rangpur  191050.39
# 3         0.873136        0.512998   0.812235    Dhaka  182901.99
# 4         0.859438        0.305328   0.776136  Rangpur  166187.94

# %% [markdown]
# ### Standardization

# %%
from sklearn.preprocessing import StandardScaler
stdscaler=StandardScaler()

# %%
df2['Marketing Spend']=stdscaler.fit_transform(df2[['Marketing Spend']])
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.897913        0.560753   2.187389    Dhaka  192261.83
# 1         1.955860        1.082807   1.949554      Ctg  191792.06
# 2         1.754364       -0.728257   1.642819  Rangpur  191050.39
# 3         1.554784       -0.096365   1.431856    Dhaka  182901.99
# 4         1.504937       -1.079919   1.286598  Rangpur  166187.94

# %%
df2['Administration']=stdscaler.fit_transform(df2[['Administration']])
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.897913        0.560753   2.187389    Dhaka  192261.83
# 1         1.955860        1.082807   1.949554      Ctg  191792.06
# 2         1.754364       -0.728257   1.642819  Rangpur  191050.39
# 3         1.554784       -0.096365   1.431856    Dhaka  182901.99
# 4         1.504937       -1.079919   1.286598  Rangpur  166187.94

# %%
df2['Transport']=stdscaler.fit_transform(df2[['Transport']])
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.897913        0.560753   2.187389    Dhaka  192261.83
# 1         1.955860        1.082807   1.949554      Ctg  191792.06
# 2         1.754364       -0.728257   1.642819  Rangpur  191050.39
# 3         1.554784       -0.096365   1.431856    Dhaka  182901.99
# 4         1.504937       -1.079919   1.286598  Rangpur  166187.94

# %% [markdown]
# ### Robust Scaler

# %%
from sklearn.preprocessing import RobustScaler
roscaler=RobustScaler()

# %%
df3['Marketing Spend']=roscaler.fit_transform(df3[['Marketing Spend']])
df3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.672530       136897.80  471784.10    Dhaka  192261.83
# 1         1.452113       151377.59  443898.53      Ctg  191792.06
# 2         1.303634       101145.55  407934.54  Rangpur  191050.39
# 3         1.156567       118671.85  383199.62    Dhaka  182901.99
# 4         1.119836        91391.77  366168.42  Rangpur  166187.94

# %%
df3['Administration']=stdscaler.fit_transform(df3[['Administration']])
df3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.672530        0.560753  471784.10    Dhaka  192261.83
# 1         1.452113        1.082807  443898.53      Ctg  191792.06
# 2         1.303634       -0.728257  407934.54  Rangpur  191050.39
# 3         1.156567       -0.096365  383199.62    Dhaka  182901.99
# 4         1.119836       -1.079919  366168.42  Rangpur  166187.94

# %%
df3['Transport']=stdscaler.fit_transform(df3[['Transport']])
df3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.672530        0.560753   2.187389    Dhaka  192261.83
# 1         1.452113        1.082807   1.949554      Ctg  191792.06
# 2         1.303634       -0.728257   1.642819  Rangpur  191050.39
# 3         1.156567       -0.096365   1.431856    Dhaka  182901.99
# 4         1.119836       -1.079919   1.286598  Rangpur  166187.94

# %% [markdown]
# ### Max Absolute Scaler

# %%
from sklearn.preprocessing import MaxAbsScaler
mascaler=MaxAbsScaler()

# %%
df4['Marketing Spend']=mascaler.fit_transform(df4[['Marketing Spend']])
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617       136897.80  471784.10    Dhaka  192261.83
# 1         0.983359       151377.59  443898.53      Ctg  191792.06
# 2         0.927985       101145.55  407934.54  Rangpur  191050.39
# 3         0.873136       118671.85  383199.62    Dhaka  182901.99
# 4         0.859438        91391.77  366168.42  Rangpur  166187.94

# %%
df4['Administration']=mascaler.fit_transform(df4[['Administration']])
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617        0.749527  471784.10    Dhaka  192261.83
# 1         0.983359        0.828805  443898.53      Ctg  191792.06
# 2         0.927985        0.553781  407934.54  Rangpur  191050.39
# 3         0.873136        0.649738  383199.62    Dhaka  182901.99
# 4         0.859438        0.500378  366168.42  Rangpur  166187.94

# %%
df4['Transport']=mascaler.fit_transform(df4[['Transport']])
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617        0.749527   1.000000    Dhaka  192261.83
# 1         0.983359        0.828805   0.940893      Ctg  191792.06
# 2         0.927985        0.553781   0.864664  Rangpur  191050.39
# 3         0.873136        0.649738   0.812235    Dhaka  182901.99
# 4         0.859438        0.500378   0.776136  Rangpur  166187.94
